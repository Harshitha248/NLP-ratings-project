# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

# importing regex
import re

# %%
# Activating the chrome browser
driver = webdriver.Chrome(r'E:/chromedriver')

# %%
# Opening the homepage of Amazon.in
driver.get('https://www.amazon.in/')
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : phones

# %%
search_bar = driver.find_element_by_id("twotabsearchtextbox")    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//div[@class="nav-search-submit nav-sprite"]/span/input')       # Locating search_button by xpath
search_button.click()

# %%
#create an empty list 
Ratings=[]
Reviews=[]

# %%
urls=driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']")
UR=[]
for i in urls:
    UR.append(i.get_attribute('href'))
for url in UR:
    driver.get(url)
    try:
        rate=driver.find_element_by_xpath("//span[@id='acrCustomerReviewText']")
        rate.click()
        rating=driver.find_element_by_xpath("//span[@class='a-size-medium a-color-base']")
        Ratings.append(rating.text)
        review=driver.find_element_by_xpath("//a[@class='a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
        Reviews.append(review.text)
    except NoSuchElementException   as e:
        Ratings.append("NO rating")
        Reviews.append("NO rating")

# %%
#checking the length of each list
print(len(Ratings))
print(len(Reviews))
# Out:
# 26
# 26

# %%
import pandas as pd
amazon=pd.DataFrame({})
amazon['Ratings']=Ratings[0:60]
amazon['Reviews']=Reviews[0:60]

# %%
amazon
# Out:
#          Ratings                                            Reviews
# 0   4.5 out of 5                    Samsung Z Fold 2 is Masterpiece
# 1     4 out of 5                                    1+ month review
# 2   4.2 out of 5                             DONT BUY THIS MOBILE .
# 3   4.2 out of 5                               Don't buy this phone
# 4   4.2 out of 5                                        WARNING !!!
# 5   4.5 out of 5            Think and evaluate before you go for it
# 6   4.3 out of 5                             Bad product don't buy😢
# 7   4.3 out of 5   This product was previously used by someone eles
# 8   4.3 out of 5                                     Awesome Design
# 9   4.3 out of 5                             Overall a good phone 👌
# 10  3.7 out of 5                               #samsunghitsbullseye
# 11  3.1 out of 5  Updated version of Android 9..Eluga I7 Enterpr...
# 12  4.2 out of 5  earphones levu. and Mobile software working sl...
# 13  4.1 out of 5                                               Hang
# 14  4.2 out of 5                  Waste of money, phones heats alot
# 15  4.4 out of 5                                              Good.
# 16  4.4 out of 5                     Best Smart Phone under 25000/-
# 17  4.2 out of 5                                Good for this Money
# 18  4.2 out of 5  Amazing design! Best NON CHINESE phone in this...
# 19  4.2 out of 5                             DONT BUY THIS MOBILE .
# 20  3.4 out of 5  Low budget friendly mobile which needs special...
# 21  4.4 out of 5                                   Value of Money 💖
# 22  4.4 out of 5                                   Value of Money 💖
# 23     NO rating                                          NO rating
# 24  3.9 out of 5                      Awesome product thanxx amazon
# 25    4 out of 5  Cutting corners from global Mi11 series and se...

# %%
amazon.to_csv('amazon_ratings_reviews2.csv', index = False)
