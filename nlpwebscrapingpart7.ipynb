# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

# importing regex
import re

# %%
# Activating the chrome browser
browser = webdriver.Chrome()

# %%
# Opening the homepage of Amazon.in
browser.get('https://www.amazon.in/')
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : printers

# %%
#create an empty list 
Ratings=[]
Reviews=[]

# %%
urls=browser.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']")
UR=[]
for i in urls:
    UR.append(i.get_attribute('href'))
for url in UR:
    browser.get(url)
    try:
        rate=browser.find_element_by_xpath("//span[@id='acrCustomerReviewText']")
        rate.click()
        rating=browser.find_element_by_xpath("//span[@class='a-size-medium a-color-base']")
        Ratings.append(rating.text)
        review=browser.find_element_by_xpath("//a[@class='a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold']")
        Reviews.append(review.text)
    except NoSuchElementException   as e:
        Ratings.append("NO rating")
        Reviews.append("NO rating")

# %%
#checking the length of each list
print(len(Ratings))
print(len(Reviews))
# Out:
# 30
# 30

# %%
import pandas as pd
amazon=pd.DataFrame({})
amazon['Ratings']=Ratings[0:29]
amazon['Reviews']=Reviews[0:29]

# %%
amazon
# Out:
#          Ratings                                            Reviews
# 0   3.6 out of 5                                    Value for money
# 1   3.7 out of 5                                              Scrap
# 2   3.7 out of 5  superb, fantastic, excellent printer, value fo...
# 3   3.5 out of 5                                Nice for 3300 rupee
# 4   3.4 out of 5                                very bad experience
# 5   4.3 out of 5                  Thank you for draining my pocket!
# 6   4.4 out of 5                      Dont buy this useless product
# 7   4.3 out of 5            Works fine, once you get it functioning
# 8   4.3 out of 5                 Read this after buying the machine
# 9   4.3 out of 5                            Faulty printer was sent
# 10  3.7 out of 5                                              Scrap
# 11  3.4 out of 5                                very bad experience
# 12  4.2 out of 5  Only MFP you need unless colour prints are req...
# 13  4.1 out of 5  No single printout have enjoyed inspite of suc...
# 14  3.4 out of 5  Don't buy this printer, you can only print 20 ...
# 15  3.8 out of 5  Good one. But care for dust control to avoid P...
# 16  3.5 out of 5  It's a great printer( discarded on Jan 24th202...
# 17  4.2 out of 5  Doesn’t work on Mac. Works good on Windows but...
# 18  4.4 out of 5                      Dont buy this useless product
# 19  4.6 out of 5  Good quality prints and zero print failures ti...
# 20  3.8 out of 5  Pathetic... received old printer and poor Amaz...
# 21  3.6 out of 5                                    Value for money
# 22  3.9 out of 5                                   It's really good
# 23  4.3 out of 5                  Thank you for draining my pocket!
# 24  3.5 out of 5                                    Average product
# 25  4.1 out of 5                                Expensive cartilage
# 26  3.7 out of 5                                              Scrap
# 27  3.8 out of 5                               Perfect for home use
# 28  3.9 out of 5                                   It's really good

# %%
amazon.to_csv('amazon_ratings_reviews6.csv', index = False)
